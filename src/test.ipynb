# %%
from functions.utils import *

file = load_file(r'D:\GithubRepositories\RAG-system\docs\doc.txt')
print(file)
# Out:
# [Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='Nguyễn Quốc Khánh sinh ngày 8 tháng 5 năm 2003. Khánh là sinh viên năm cuối ngành công nghệ thông tin tại Học viện Công nghệ Bưu chính viễn thông. Hiện tại Khánh đang theo đuổi ước mơ trở thành một kỹ sư AI. Trình độ tiếng Anh của Khánh là 885 điểm toeic 2 ở kỹ năng Nghe và Đọc')]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(chunk_size=10, chunk_overlap=2)
chunks = splitter.split_documents(file)
print(chunks)
# Out:
# [Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='Nguyễn'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='Quốc'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='Khánh'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='sinh ngày'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='8 tháng 5'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='5 năm'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='2003.'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='Khánh là'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='sinh viên'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='năm cuối'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='ngành'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='công nghệ'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='thông tin'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='tại Học'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='viện Công'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='nghệ Bưu'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='chính'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='viễn'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='thông.'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='Hiện tại'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='Khánh'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='đang theo'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='đuổi ước'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='mơ trở'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='thành một'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='kỹ sư AI.'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='Trình độ'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='tiếng Anh'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='của Khánh'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='là 885'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='điểm'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='toeic 2 ở'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='ở kỹ năng'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='Nghe và'), Document(metadata={'source': 'D:\\GithubRepositories\\RAG-system\\docs\\doc.txt'}, page_content='Đọc')]

# %%
import json

for chunk in chunks:
    json.dumps(chunk)
